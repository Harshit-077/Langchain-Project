# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
# !pip install -q pinecone
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install -q pinecone-client
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --upgrade -q pinecone-client
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from pinecone import Pinecone
pc = Pinecone()
pc.list_indexes()
# Out:
# []

# %%
from pinecone import ServerlessSpec
index_name = "langchain"
if index_name not in pc.list_indexes().names():
    print(f"Creating index {index_name}")
    pc.create_index(
        name=index_name,
        dimension=1536,
        metric='cosine',
        spec=ServerlessSpec(
            cloud='aws',
            region='us-east-1',
        )
    )
    print("Index created")
else:
    print(f"Index {index_name} already exists")
# Out:
# Creating index langchain
# Index created

# %%
index_name = "langchain"
if index_name  in pc.list_indexes().names():
    print(f"Deleting index {index_name}")
    pc.delete_index(index_name)
    print("Done")
else:
    print(f"Index {index_name} does not exist")
# Out:
# Deleting index langchain
# Done

# %%
index = pc.Index(index_name)
print(index.describe_index_stats())
# Out:
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '151',
#                                     'content-type': 'application/json',
#                                     'date': 'Thu, 26 Mar 2026 17:38:14 GMT',
#                                     'grpc-status': '0',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '84',
#                                     'x-pinecone-request-latency-ms': '84',
#                                     'x-pinecone-response-duration-ms': '86'}},
#  'dimension': 1536,
#  'index_fullness': 0.0,
#  'memoryFullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {},
#  'storageFullness': 0.0,
#  'total_vector_count': 0,
#  'vector_type': 'dense'}

# %% [markdown]
# ## Vectors

# %%
import random

vectors = [[random.random() for _ in range(1536)] for v in range(5)]
# print(vectors)
ids = list('abcde')

index_name = "langchain"
index = pc.Index(index_name)
index.upsert(vectors = zip(ids, vectors))
# Out:
# UpsertResponse(upserted_count=5, _response_info={'raw_headers': {'date': 'Mon, 30 Mar 2026 10:35:20 GMT', 'content-type': 'application/json', 'content-length': '19', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '5', 'x-pinecone-request-logical-size': '30725', 'x-pinecone-request-latency-ms': '1063', 'x-envoy-upstream-service-time': '175', 'x-pinecone-response-duration-ms': '1065', 'grpc-status': '0', 'server': 'envoy'}})

# %%
index.upsert(vectors=[('c',[0.5]* 1536)])
# Out:
# UpsertResponse(upserted_count=1, _response_info={'raw_headers': {'date': 'Mon, 30 Mar 2026 10:35:25 GMT', 'content-type': 'application/json', 'content-length': '19', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '6', 'x-pinecone-request-logical-size': '6145', 'x-pinecone-request-latency-ms': '157', 'x-envoy-upstream-service-time': '158', 'x-pinecone-response-duration-ms': '160', 'grpc-status': '0', 'server': 'envoy'}})

# %%
index.fetch(ids = ['c','d'])
# Out:
# FetchResponse(namespace='', vectors={'d': Vector(id='d', values=[0.902918339, 0.11073821, 0.123624794, 0.197645351, 0.259564728, 0.221239626, 3.27119706e-05, 0.798084378, 0.67394048, 0.403555274, 0.082440719, 0.0365289561, 0.180683821, 0.375547111, 0.424567968, 0.53775394, 0.844473183, 0.517074823, 0.74762845, 0.509011388, 0.81026119, 0.341521561, 0.397781193, 
.6977759, 0.823436618, 0.0926112533, 0.445578307, 0.131454393, 0.927164733, 0.0906465501, 0.201377, 0.679303944, 0.780702353, 0.939586699, 0.122226402, 0.527722359, 0.0719315484, 0.00578834396, 0.282545567, 0.978904843, 0.684766054, 0.629480958, 0.462884, 0.394488841, 0.0277572311, 0.978224933, 0.781004667, 0.701713264, 0.566295743, 0.359490752, 0.119915992, 0.941367805, 0.276567161, 0.65606904, 0.705059767, 0.045878496, 0.12156067, 0.994575322, 0.569153607, 0.63444072, 0.929325938, 0.0422450639, 0.472382724, 0.0372217894, 0.796185851, 0.862011075, 0.296836585, 0.715045393, 0.84508568, 0.936647, 0.53788054, 0.594027519, 0.136701822, 0.818928599, 0.205594495, 0.226678565, 0.770134747, 0.779129326, 0.304716885, 0.32404691, 0.312273741, 0.694243193, 0.986384332, 0.0507756695, 0.0198070146, 0.509554386, 0.24888289, 0.949071825, 0.347241491, 0.1 ...

# %%
index.delete(ids=['c','b'])
# Out:
# {'_response_info': {'raw_headers': {'date': 'Mon, 30 Mar 2026 10:31:33 GMT',
#    'content-type': 'application/json',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-pinecone-request-lsn': '4',
#    'x-pinecone-request-logical-size': '0',
#    'x-pinecone-request-latency-ms': '127',
#    'x-envoy-upstream-service-time': '128',
#    'x-pinecone-response-duration-ms': '129',
#    'grpc-status': '0',
#    'server': 'envoy'}}}

# %%
index.describe_index_stats()
# Out:
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '182',
#                                     'content-type': 'application/json',
#                                     'date': 'Mon, 30 Mar 2026 10:35:37 GMT',
#                                     'grpc-status': '0',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '5',
#                                     'x-pinecone-request-latency-ms': '4',
#                                     'x-pinecone-response-duration-ms': '6'}},
#  'dimension': 1536,
#  'index_fullness': 0.0,
#  'memoryFullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'__default__': {'vector_count': 6}},
#  'storageFullness': 0.0,
#  'total_vector_count': 6,
#  'vector_type': 'dense'}

# %%
index.fetch(ids=['x'])
# Out:
# FetchResponse(namespace='', vectors={}, usage={'read_units': 1}, _response_info={'raw_headers': {'date': 'Mon, 30 Mar 2026 10:35:42 GMT', 'content-type': 'application/json', 'content-length': '53', 'connection': 'keep-alive', 'x-pinecone-request-latency-ms': '49', 'x-envoy-upstream-service-time': '50', 'x-pinecone-response-duration-ms': '52', 'grpc-status': '0', 'server': 'envoy'}})

# %%
query_vector = [random.random() for _ in range(1536)]

# %%
res = index.query(
    vector = query_vector,
    top_k = 3,
    include_values = True,
    include_metadata=True
)
for match in res.matches:
    print(f"ID: {match.id}")
    print(f"Score: {match.score}")
    print(f"Metadata: {match.metadata}")
    print("-" * 30)
# Out:
# ID: c
# Score: 0.868418097
# Metadata: None
# ------------------------------
# ID: b
# Score: 0.746530294
# Metadata: None
# ------------------------------
# ID: a
# Score: 0.746023417
# Metadata: None
# ------------------------------
