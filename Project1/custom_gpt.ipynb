# %% [markdown]
# ## Custom GPT using Langchain

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(),override=True)
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage
from langchain_classic.chains import create_retrieval_chain
from langchain_classic.memory import ConversationBufferMemory
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, MessagesPlaceholder

llm = ChatGroq(
    model = 'llama-3.3-70b-versatile',
    temperature=1
)

memory = ConversationBufferMemory(
    memory_key='chat_history',
    return_messages=True,
)

prompt = ChatPromptTemplate(
    input_variables = ['content'],
    messages= [
        SystemMessage(content= "You are a chatbot, having conversation with a human."),
        MessagesPlaceholder(variable_name='chat_history'),
        HumanMessagePromptTemplate.from_template('{content}')
    ]
)

chain = prompt | llm

while True:
    content = input("Your prompt: ")
    if content in ['quit', 'exit', 'bye']:
        print('Goodbye')
        break

    memory_variables = memory.load_memory_variables({})

    # Run chain
    response = chain.invoke({
        "content": content,
        "chat_history": memory_variables["chat_history"]
    })

    print(response.content)
    print('-'*50)

    memory.save_context(
        {"content": content},
        {"output": response.content}
    )
# Out:
# The people of India.  India is a vast and diverse country with a population of over 1.3 billion people, making it the second-most populous country in the world. The Indian population is a unique blend of different cultures, languages, religions, and ethnicities.
#
# **Diversity of Religions:**
# India is home to a wide range of religions, including Hinduism, Islam, Christianity, Sikhism, Buddhism, Jainism, and many others. The majority of the population (around 80%) follows Hinduism, while Islam is the second-largest religion, accounting for around 15% of the population.
#
# **Language:**
# India has 22 officially recognized languages, with Hindi being the most widely spoken. English is also widely spoken, especially in urban areas and among the educated population. Other popular languages include Bengali, Marathi, Telugu, and Tamil.
#
# **Ethnic Groups:**
# India is home to a diverse range of ethnic groups, including:
#
# 1. **Indo-Aryans**: Found in northern and western India, they are the largest ethnic group in the country.
# 2. **Dravidians**: Predominantly found in southern India, they have a distinct culture and language.
# 3. **Mongoloids**: Found in eastern and northeastern India, they have a unique culture and language.
# 4. **Tribals**: There are over 400 tribal communities in India, each with their own distinct culture and traditions.
#
# **Caste System:**
# The Indian society has historically been divided into a complex caste system, with different castes having different social and economic status. Although the caste system is not as rigid as it used to be, it still plays a significant role in shaping Indian society.
#
# **Family and Social Structure:**
# Family is highly valued in Indian culture, with extended families being very common. The joint family system, where multiple generations live together, is still prevalent in many parts of the country. Respect for elders and tradition is deeply ingrained in Indian culture.
#
# **Regional Variations:**
# Each region in India has its own unique culture, food, music, and traditions. For example:
#
# 1. **North India**: Known for its rich history, vibrant cities, and popular tourist destinations like the Taj Mahal and the Golden Temple.
# 2. **South India**: Famous for its beautiful beaches, delicious cuisine, and ancient temples like the Meenakshi Amman Temple.
# 3. **East India**: Home to the majestic Himalayas, the region is known for its stunning natural beauty and vibrant cultural festivals like the Durga Puja.
# 4. **West India**: Known for its vibrant cities like Mumbai and Ahmedabad, the region is famous for its rich history, beautiful beaches, and delicious cuisine.
#
# **Modern India:**
# Today, India is a rapidly changing country, with a growing economy, a thriving technology sector, and a young population. Indians are known for their resilience, adaptability, and entrepreneurial spirit, making them a significant part of the global workforce.
#
# This is just a brief glimpse into the rich tapestry of the Indian population. The diversity, complexity, and vibrancy of Indian culture are truly unique and fascinating. Is there anything specific you'd like to know more about?
# --------------------------------------------------
# A fascinating comparison.  The people of India and Europe have many differences, but also some interesting similarities. Here are a few key aspects:
#
# **Cultural Differences:**
#
# 1. **Family and Social Structure:** Indian families tend to be more tightly knit and hierarchical, with a strong emphasis on respect for elders and tradition. In contrast, European families often have a more individualistic approach, with a focus on personal freedom and independence.
# 2. **Communication Styles:** Indians tend to be more expressive and emotive in their communication, using a lot of gestures, tonal nuances, and emotional appeals. Europeans, on the other hand, tend to be more direct, literal, and reserved in their communication.
# 3. **Food and Dining:** Indian cuisine is known for its rich, diverse, and often spicy flavors, with a strong emphasis on communal dining and sharing food. European cuisine, while also diverse, tends to be more straightforward and individualized, with a focus on fine dining and culinary sophistication.
# 4. **Religion and Spirituality:** India is a highly spiritual country, with a strong emphasis on Hinduism, Islam, and other Eastern faiths. Europe, on the other hand, has a more secular approach, with a greater emphasis on Christianity and a more individualized approach to spirituality.
#
# **Similarities:**
#
# 1. **Educational Emphasis:** Both Indian and European cultures place a high value on education, with a strong emphasis on academic achievement, critical thinking, and intellectual curiosity.
# 2. **Respect for Tradition:** Both Indian and European cultures have a deep respect for tradition, history, and cultural heritage, with a strong emphasis on preserving and passing down customs, legends, and historical narratives.
# 3. **Love of Music and Arts:** Both Indian and European cultures have a rich tradition of music, dance, and art, with a strong emphasis on creative expression, innovation, and cultural exchange.
# 4. **Warm Hospitality:** Both Indian and European cultures are known for their warm hospitality, with a strong emphasis on welcoming guests, sharing food and drink, and showing respect for others.
#
# **Demographic Differences:**
#
# 1. **Age:** Europe has an aging population, with a median age of around 42 years. India, on the other hand, has a relatively young population, with a median age of around 28 years.
# 2. **Urbanization:** India is rapidly urbanizing, with around 30% of the population living in cities. Europe, on the other hand, is already highly urbanized, with around 75% of the population living in cities.
# 3. **Economic Disparities:** India has significant economic disparities, with a large gap between the rich and the poor. Europe, while also experiencing economic disparities, tends to have a more comprehensive social safety net and a more equitable distribution of wealth.
#
# **Psychological Differences:**
#
# 1. **Individualism vs. Collectivism:** Indians tend to be more collectivist, prioritizing family, community, and social harmony over individual needs and desires. Europeans, on the other hand, tend to be more individualistic, prioritizing personal freedom, autonomy, and self-expression.
# 2. **Risk-Taking and Entrepreneurship:** Indians are often seen as more entrepreneurial and risk-tolerant, with a strong emphasis on starting new businesses and pursuing innovative ventures. Europeans, while also entrepreneurial, tend to be more cautious and risk-averse, with a stronger emphasis on stability and security.
# 3. **Time and Punctuality:** Indians tend to have a more flexible and relaxed attitude towards time, with a focus on relationships and social interactions over punctuality and efficiency. Europeans, on the other hand, tend to be more time-conscious and punctual, with a strong emphasis on meeting deadlines and respecting schedules.
#
# These are just a few of the many differences and similarities between the people of India and Europe. Both cultures have their unique strengths, weaknesses, and nuances, and there is much to be learned from each other's perspectives and approaches to life.
# --------------------------------------------------
# Goodbye
