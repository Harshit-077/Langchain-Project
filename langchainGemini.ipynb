# %% [markdown]
# # Langchain and Google Gemini

# %%
from langchain_core.output_parsers import StrOutputParser
# !pip install -q langchain-google-genai
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --upgrade -q langchain-google-genai
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip show langchain-google-genai
# Out:
# Name: langchain-google-genai
# Version: 4.2.1
# Summary: An integration package connecting Google's genai package and LangChain
# Home-page: https://docs.langchain.com/oss/python/integrations/providers/google
# Author:
# Author-email:
# License: MIT
# Location: /Users/Harshit/Downloads/Work_fol/internProj/.venv/lib/python3.12/site-packages
# Requires: filetype, google-genai, langchain-core, pydantic
# Required-by:

# %%
# !pip install -q google-generativeai
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), verbose=True)
# Out:
# True

# %%
import getpass
import os

if 'GOOGLE_API_KEY' not in os.environ:
    os.environ['GOOGLE_API_KEY'] = getpass.getpass("Provide your Google API key: ")

# %%
from google import genai
client = genai.Client()
for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview

# %% [markdown]
# ## Integrating Langchain + Gemini

# %% [markdown]
# #### Switched to Groq because of no credit

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(
    model = 'llama-3.3-70b-versatile',
    temperature = 0.9,
)

response = llm.invoke('Write a paragraph about live on mars in year 2100.')
print(response.content)
# Out:
# As the year 2100 dawns, human civilization has finally achieved its long-held dream of establishing a thriving colony on Mars. The once-barren landscape is now teeming with life, as towering domed cities and sprawling metropolises stretch across the planet's surface. Mars' inhabitants, a diverse population of scientists, engineers, and their families, live and work in a futuristic, self-sustaining environment, where cutting-edge technology and innovative architecture have created a unique and vibrant culture. With advanced life support systems and renewable energy sources, the Martian colony is able to harness the planet's resources, recycle its waste, and maintain a delicate balance with the harsh environment. As the colony continues to grow and evolve, its residents are pushing the boundaries of scientific discovery, exploring the Martian wilderness, and forging a new, interplanetary identity that is distinct from, yet connected to, their Earthly heritage.

# %%
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import create_retrieval_chain

prompt = PromptTemplate.from_template("You are a content creator. Write me a tweet about {topic}")

chain = prompt | llm
topic = "Artificial intelligence"
result = chain.invoke({"topic": topic})
print(result.content)
# Out:
# "Unlocking the future: Artificial Intelligence is revolutionizing the way we live and work. From virtual assistants to self-driving cars, AI is transforming industries and pushing boundaries. What's the most exciting AI innovation you're looking forward to? #AI #FutureTech"
